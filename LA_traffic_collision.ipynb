# %% [markdown]
# [View in Colaboratory](https://colab.research.google.com/github/bryant-vu/ThirdGradeThrowBack/blob/master/LA_traffic_collision.ipynb)

# %% [markdown]
# # LA Collision Data since 2010
#
# ## Data Import
#
#  - Brief description of the dataset
#
#  - Link to the dataset
#
#  - MO Code library
#     - Import MO Code Description
#
#  - Data Dictionary
#
# | Column Name | Description | Type |
# | --- | :---: | :--: |
# |DR Number | Division of Records Number: Official file number made up of a 2 digit year, area ID, and 5 digits. | Plain Text |
# | Date Reported | MM/DD/YYYY | Date & Time |
# | Date Occurred | MM/DD/YYYY | Date & Time |
# | Time Occurred | In 24 military time. | Plain Text |
# | Area ID | The LAPD has 21 Community Police Stations referred to as Geographic Areas within the department. These Geographic Areas are sequentially numbered from 1-21. | Plain Text |
#
# ## Filling in NA values
#
# We would like to explore running a (1) dirty model, (2) running a cleaned model filled with analytics, and (3) running a cleaned model filled with ML.
#
# ## Data Explore:
#   - Which race gets the most accidents
#   - Frequent victims
#   - Frequent perpatrators
#   - Which location is accident prone
#   - When are accidents likely to occur
#
# ## Feature Engineering
#   - Features to generate
#
# ## Initial Model
#   - What question can we answer with a model (RF, regression, gradient boost)
#   - Create simple baseline model (logistic, kmeans...)
#     - Explain some stats
#   - Create higher level model (ensemble, NN...)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import io
# %matplotlib inline
sns.set()

# %% [markdown]
# import matplotlib.pyplot as plt
# import seaborn as sns
# %matplotlib inline
# sns.set()

# %%
# Upload for Phi
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-b0fa12a1-a13f-4345-8652-a1e77ccda72d" name="files[]" multiple disabled />
#      <output id="result-b0fa12a1-a13f-4345-8652-a1e77ccda72d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Traffic_Collision_Data_from_2010_to_Present.csv to Traffic_Collision_Data_from_2010_to_Present.csv

# %%
# Upload for Bryant
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-522f41b4-7d8c-4b37-a9b1-1b7ab24485c8" name="files[]" multiple disabled />
#      <output id="result-522f41b4-7d8c-4b37-a9b1-1b7ab24485c8">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Traffic_Collision_Data_from_2010_to_Present.csv to Traffic_Collision_Data_from_2010_to_Present (2).csv

# %%
# read table
df = pd.read_csv(io.StringIO(uploaded['Traffic_Collision_Data_from_2010_to_Present.csv'].decode('utf-8')))

# %%
df.head(50)
# Out:
#     DR Number   Date Reported Date Occurred  Time Occurred  Area ID  \
# 0   100119684  01/01/11042010    11/04/2010           1345        1
# 1   101221255   01/01/8102010    08/10/2010           1900       12
# 2   101414426   01/01/6112010    06/09/2010           1925       14
# 3   102109168   01/01/4062010    04/06/2010           1445       21
# 4   100322445   01/01/9222010    05/23/2010           1805        3
# 5   101616651   01/01/9022010    09/02/2010           1520       16
# 6   101226806  01/01/10282010    10/27/2010           1910       12
# 7   101224882   01/01/9302010    09/30/2010            540       12
# 8   111206659   01/01/2082011    11/19/2010           1440       12
# 9   101307375   01/01/2212010    02/21/2010            300       13
# 10  100621779   01/01/9012010    09/01/2010           1530        6
# 11  101209393   01/01/3112010    03/11/2010           1840       12
# 12  101508936   01/01/3232010    03/23/2010           1400       15
# ...

# %%
df.shape
# Out:
# (422724, 18)

# %%
df.dtypes
# Out:
# DR Number                   int64
# Date Reported              object
# Date Occurred              object
# Time Occurred               int64
# Area ID                     int64
# Area Name                  object
# Reporting District          int64
# Crime Code                  int64
# Crime Code Description     object
# MO Codes                   object
# Victim Age                float64
# Victim Sex                 object
# Victim Descent             object
# Premise Code              float64
# Premise Description        object
# Address                    object
# Cross Street               object
# Location                   object
# dtype: object

# %%
df.isnull().sum()
# Out:
# DR Number                     0
# Date Reported                 0
# Date Occurred                 0
# Time Occurred                 0
# Area ID                       0
# Area Name                     0
# Reporting District            0
# Crime Code                    0
# Crime Code Description        0
# MO Codes                  83600
# Victim Age                36382
# Victim Sex                 5719
# Victim Descent             6169
# Premise Code                 27
# Premise Description        1215
# Address                       0
# Cross Street              18491
# Location                      0
# dtype: int64
